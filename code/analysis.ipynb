# %%
from data_load import load_data
from visualization import visualize_volume_avg_hour
from data_processing import transform_avg_volume_hourly

# %%
data_dict = load_data()

# %%
STB_avg_hourly, SAB_avg_hourly = transform_avg_volume_hourly(data_dict)
visualize_volume_avg_hour(STB_avg_hourly, SAB_avg_hourly)
# Out:
# /Users/hoapham/Documents/Learning/thesis/code/visualization.py:13: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax1.set_xticklabels(["00:00", "03:00", "06:00", "09:00", "12:00", "15:00", "18:00", "21:00", "00:00"])
